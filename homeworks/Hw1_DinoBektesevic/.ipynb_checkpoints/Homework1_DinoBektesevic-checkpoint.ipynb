# %% [markdown]
# # Astrostatistics Homework 1
# 11/01/2018 Dino Bektesevic
#
# [Reading HLC file and filtering functions](#reading_filtering)
# [Plotting function](#plot_function)
# [Hess plot, Ra and Dec Proper motion plots for stars](#stars_plots)
# [Hess plot, Ra and Dec Proper motion plots for galaxies](#galaxies_plots)
# [Additional plots](#addons)

# %%
import numpy as np

import matplotlib as mpl
from matplotlib import pyplot as plt

import astropy as apy
from astropy.table import Table

import astroML as aml
from astroML.plotting import setup_text_plots
from astroML.stats import binned_statistic_2d

setup_text_plots(usetex=True)

# %%
mpl.rcParams['figure.figsize'] = (20,8)
mpl.rcParams["axes.labelsize"] = 20
mpl.rcParams["font.size"] = 24
mpl.rcParams['xtick.labelsize'] = 14
mpl.rcParams['ytick.labelsize'] = 14
filelist = ["HLC.RA_00_to_01.fits", "HLC.RA_01_to_02.fits", "HLC.RA_02_to_03.fits", 
            "HLC.RA_03_to_04.fits", "HLC.RA_20_to_21.fits", "HLC.RA_21_to_22.fits", 
            "HLC.RA_22_to_23.fits", "HLC.RA_23_to_24.fits"]

# %% [markdown]
# ## Reading and filtering
# <a id='reading_filtering'></a>

# %%
def filter_stars(table):
    star_type_mask = table['MEAN_OBJECT_TYPE'] > 5
    return table[star_type_mask]
    
def filter_galaxies(table):
    star_type_mask = table['MEAN_OBJECT_TYPE'] == 3
    return table[star_type_mask]

def filter_pm(table):
    dec_pm_min = np.abs(table["DEC_PM_CLIP"]) < 0.04
    dec_pm_max = np.abs(table["DEC_PM_CLIP"]) >= 0
    ra_pm_min = np.abs(table["RA_PM_CLIP"]) < 0.04
    ra_pm_max = np.abs(table["RA_PM_CLIP"]) >= 0
    return table[dec_pm_min & dec_pm_max & ra_pm_max & ra_pm_max]
    

def read_hlc_file(filename = "HLC.RA_02_to_03.fits", objfilter="stars", extra=False, absval=True):
    f = apy.io.fits.open(filename)
    table = Table(f[1].data)
    
    if objfilter == "stars":
        table = filter_stars(table)
        #table = filter_pm(table)
    elif objfilter == "galaxies":
        table = filter_galaxies(table)
    elif objfilter == "off" or objfilter is None:
        pass
    else:
        raise ValueError("Unknown option for objfilter: {0}".format(objfilter))

    #get interesting values
    mags = Table(table['MEAN_PSFMAG_CLIP'], names=('u', 'g', 'r', 'i','z')) 
    if absval:
        rapm = np.abs(table['RA_PM_CLIP'].data)
        decpm = np.abs(table['DEC_PM_CLIP'].data)
    else:
        rapm = table['RA_PM_CLIP'].data
        decpm = table['DEC_PM_CLIP'].data
    if extra:
        ra = table["RA_MEAN_CLIP"].data
        dec = table["RA_MEAN_CLIP"].data
        return mags, rapm, decpm, ra, dec
    
    return mags, rapm, decpm

# %% [markdown]
# ## Plot function
# <a id='plot_function'></a>

# %%
def hess_gri_pm(mags, ra, dec, title=""):
    
    num_bins = 500
    minx, maxx = -2, 5
    miny, maxy = 10, 25
    #levels = np.array([ 0.97715262,  1.46572894,  1.95430525,  2.44288156,  2.93145787])
    levels = [1, 2, 3]
    
    gmi = mags["g"] - mags["i"]
    r = mags["r"]
       
    fig = plt.figure(figsize=(15, 6))
    fig.subplots_adjust(wspace=0.22, left=0.1, right=0.95, bottom=0.12, top=0.90)
    suptitle = title.replace("_", " ")
    fig.suptitle(suptitle)
    
    N,       xedge,    yedge    = binned_statistic_2d(gmi, r, gmi, 'count', bins=num_bins)
    ramed,   raxedge,  rayedge  = binned_statistic_2d(gmi, r, ra,  'median', bins=num_bins)
    decmed,  decxedge, decyedge = binned_statistic_2d(gmi, r, dec, 'median', bins=num_bins) 
    
    #############################################################################################################
    # First
    #############################################################################################################
    ax = plt.subplot(131) 

    plt.imshow(np.log10(N.T), origin='lower', aspect="auto", 
               extent=[xedge[0], xedge[-1], yedge[0], yedge[-1]])
    cb = plt.colorbar(pad=0.14, format=r'$10^{%i}$', orientation='horizontal')
    
    cb.set_label(r"$N_{\mathrm{stars}}$")
    plt.clim(0, 3)
    
    plt.xlabel(r"$g-i$")
    plt.ylabel(r"$r$")
    
    plt.xlim(minx, maxx)
    plt.ylim(miny, maxy)
    
    plt.gca().invert_yaxis()
    
    #############################################################################################################
    # Second
    #############################################################################################################
    ax = plt.subplot(132) 

    i = plt.imshow(ramed.T, origin='lower', aspect="auto",
               extent=[raxedge[0], raxedge[-1], rayedge[0], rayedge[-1]])
    cb = plt.colorbar(pad=0.14 , orientation='horizontal')
    plt.contour(np.log10(N.T), origin='lower', colors="k", levels=levels,
                extent=[xedge[0], xedge[-1], yedge[0], yedge[-1]])
    
    cb.set_label(r"$\mathrm{median}(\mu_{\alpha})$")
    i.set_clim(0, 0.03)
    
    plt.xlabel(r"$g-i$")
    plt.ylabel(r"$r$")
    
    plt.xlim(minx, maxx)
    plt.ylim(miny, maxy)
    
    plt.gca().invert_yaxis()
    
    
    #############################################################################################################
    # Third
    #############################################################################################################
    ax = plt.subplot(133) 

    i = plt.imshow(decmed.T, origin='lower', aspect="auto",
               extent=[decxedge[0], decxedge[-1], decyedge[0], decyedge[-1]])
    cb = plt.colorbar(pad=0.14 , orientation='horizontal')
    plt.contour(np.log10(N.T), origin='lower', levels=levels, colors="k",
                extent=[xedge[0], xedge[-1], decyedge[0], decyedge[-1]])
    
    
    cb.set_label(r"$\mathrm{median}(\mu_{\delta})$")
    i.set_clim(0, 0.03)
    
    plt.xlabel(r"$g-i$")
    plt.ylabel(r"$r$")
    
    plt.xlim(minx, maxx)
    plt.ylim(miny, maxy)
    
    plt.gca().invert_yaxis()
    plt.show()

# %% [markdown]
# ## Hess and Proper Motion plots for stars
# <a id='star_plots'></a>

# %%
for filename in filelist:
    mags, rapm, decpm = read_hlc_file(filename, objfilter="stars")
    hess_gri_pm(mags, rapm, decpm, title=filename)
# Out:
# /home/dino/.conda/envs/DSFP2/lib/python2.7/site-packages/ipykernel_launcher.py:26: RuntimeWarning: divide by zero encountered in log10
# /home/dino/.conda/envs/DSFP2/lib/python2.7/site-packages/ipykernel_launcher.py:49: RuntimeWarning: divide by zero encountered in log10
# /home/dino/.conda/envs/DSFP2/lib/python2.7/site-packages/ipykernel_launcher.py:72: RuntimeWarning: divide by zero encountered in log10

# %% [markdown]
# ## Hess and Proper Motion plots for galaxies
# <a id='galaxies_plots'></a>

# %%
for filename in filelist:
    mags, rapm, decpm = read_hlc_file(filename, objfilter="galaxies")
    hess_gri_pm(mags, rapm, decpm, title=filename)
# Out:
# /home/dino/.conda/envs/DSFP2/lib/python2.7/site-packages/ipykernel_launcher.py:26: RuntimeWarning: divide by zero encountered in log10
# /home/dino/.conda/envs/DSFP2/lib/python2.7/site-packages/ipykernel_launcher.py:49: RuntimeWarning: divide by zero encountered in log10
# /home/dino/.conda/envs/DSFP2/lib/python2.7/site-packages/ipykernel_launcher.py:72: RuntimeWarning: divide by zero encountered in log10

# %% [markdown]
# ## Additional plots
#
# <a id='addons'></a>

# %%
mags, rapm, decpm = read_hlc_file("HLC.RA_00_to_01.fits", objfilter=None, absval=False)
smags, srapm, sdecpm = read_hlc_file("HLC.RA_00_to_01.fits", objfilter="stars", absval=False)
gmags, grapm, gdecpm = read_hlc_file("HLC.RA_00_to_01.fits", objfilter="galaxies", absval=False)

# %%
fig = plt.figure(figsize=(20, 7))
ax1 = plt.subplot2grid((1, 3), (0, 0))
ax2 = plt.subplot2grid((1, 3), (0, 1), sharey=ax1)
ax3 = plt.subplot2grid((1, 3), (0, 2))

ax1.scatter(decpm, rapm, s=7, color="blue")
ax1.scatter(1000, 1000, label="All", color="blue")
ax1.legend(fontsize=20)
ax1.set_xlim(-200, 200)
ax1.set_ylim(-200, 200)

ax2.scatter(sdecpm, srapm, color="black", s=5)
ax2.scatter(gdecpm, grapm, color="gray", alpha=0.4, s=5)
ax2.scatter(1000, 1000, color="black", label="Stars")
ax2.scatter(1000, 1000, color="gray", label="Galaxies")
ax2.legend(fontsize=20)
ax2.set_xlim(-200, 200)
ax2.set_ylim(-200, 200)

ax3.scatter(gdecpm, grapm, color="gray", label="Galaxies", s=3.9)
ax3.scatter(sdecpm, srapm, color="black", label="Stars", alpha=0.6, s=3.9)
ax3.set_xlim(-20, 20)
ax3.set_ylim(-20, 20)

plt.show()

# %%
from matplotlib.colors import LogNorm


fig, axes = plt.subplots(1, 2, figsize=(16, 7))
h = axes[0].hist2d(sdecpm, srapm, bins=150, norm=LogNorm(), range=[[-0.2, 0.2], [-0.2, 0.2]])
plt.colorbar(h[3], ax=axes[0])

h = axes[1].hist2d(gdecpm, grapm, bins=150, norm=LogNorm(), range=[[-0.2, 0.2], [-0.2, 0.2]])
plt.colorbar(h[3], ax=axes[1])

plt.show()
